# %% [markdown]
# <a href="https://colab.research.google.com/github/rakhim-ova/week1_lab/blob/main/week1_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Zarnigor Raximova"

# %%
my_enrollment_number = "A85205225033"

# %%
my_hobby = "Watching YouTube"

# %%
print("Hello, my name is {}, and my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is Zarnigor Raximova, and my enrollment number is A85205225033. I like Watching YouTube.
